# %%
from snakemake.io import expand
import pandas as pd
import yaml
import pdb
import re
import numpy as np
import pyranges as pr
from utils import *

# %%
config_file = 'config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %% [markdown]
# ## 230627 get the chr restructuring right

# %%
gff_file = 'data/human/raw/Placenta_Placenta_ont_pre-capture_human_all.gff'

# %%
gff_rm_sirv(gff_file, 'test')

# %% [markdown]
# ## 230626 which chromosomes are in the reference fasta and not in the input gffs (or vice vers)

# %%
# df = pr.read_gff('data/human/Liver_Adult_pacBioSII_pre-capture_human_all.gff').as_df()
import glob
import pyranges as pr

chrs = []
for f in glob.glob('data/human/raw/*gff'):
    print(f)
    df = pr.read_gff(f).as_df()
    chrs += df.Chromosome.unique().tolist()
    chrs = list(set(chrs))
    
    
with open('chrs.txt', 'w') as ofile:
    ofile.write(','.join(chrs))

# %%
# chrs = df.Chromosome.unique().tolist()
# chrs

# %%
chrs = ['KI270742.1','KI270746.1','GL000224.1','KI270719.1','KI270743.1','KI270717.1','GL000213.1',\
        'KI270754.1','chr20','KI270718.1','chr5','GL000009.2','KI270733.1','GL000205.2','KI270745.1',\
        'GL000220.1','KI270750.1','chr3','KI270721.1','KI270713.1','KI270720.1',\
        'GL000218.1','KI270726.1','chr1','SIRVome_isoforms','chr2','chr12','chrM',\
        'KI270734.1','GL000225.1','KI270755.1','GL000008.2','KI270706.1','chr17','KI270727.1',\
        'chr13','chr19','chr21','KI270722.1','KI270749.1','chr11','KI270751.1','chrY','chr16',\
        'KI270711.1','GL000214.1','KI270714.1','chr8','chr4','GL000221.1','chr9','chrX','KI270744.1',\
        'chr15','KI270753.1','KI270731.1','chr6','chr18','KI270725.1','GL000194.1','KI270712.1','chr7',\
        'KI270442.1','GL000195.1','KI270748.1','chr14','KI270741.1','KI270728.1','GL000219.1','chr10','KI270710.1','chr22']

# %%
gff_df = pd.DataFrame(data=chrs, columns=['Chromosome'])
gff_df.head()
# Out:
#    Chromosome
# 0  KI270742.1
# 1  KI270746.1
# 2  GL000224.1
# 3  KI270719.1
# 4  KI270743.1

# %%
# ! gzcat ~/Desktop/hg38.fa.gz | grep '^>' > human_ref_chrs.txt

# %%
fa_df = pd.read_csv('human_ref_chrs.txt',header=None)
fa_df.columns = ['chr']
fa_df['Chromosome'] = fa_df.chr.str.split('>', n=1, expand=True)[1]
fa_df = fa_df[['Chromosome']]

# %%
fa_df
fa_chrs = fa_df.Chromosome.unique().tolist()

# %%
list(set(fa_chrs)-set(chrs))
# Out:
# ['chrUn_KI270374v1',
#  'chrUn_KI270373v1',
#  'chr11_KI270721v1_random',
#  'chrUn_KI270466v1',
#  'chrUn_KI270418v1',
#  'chrUn_KI270387v1',
#  'chrUn_KI270579v1',
#  'chr16_KI270856v1_alt',
#  'chrUn_KI270747v1',
#  'chr17_GL383564v2_alt',
#  'chr17_KI270857v1_alt',
#  'chr12_KI270834v1_alt',
#  'chr19_KI270922v1_alt',
#  'chrUn_KI270749v1',
#  'chr14_KI270724v1_random',
#  'chr22_KI270731v1_random',
#  'chr9_KI270823v1_alt',
#  'chr16_KI270854v1_alt',
#  'chr7_KI270807v1_alt',
#  'chr19_GL949749v2_alt',
#  'chr12_KI270904v1_alt',
#  'chr6_GL000252v2_alt',
#  'chr14_GL000194v1_random',
#  'chr18_GL383570v1_alt',
#  'chrUn_GL000224v1',
#  'chrUn_KI270322v1',
#  'chrUn_KI270529v1',
#  'chr19_GL949748v2_alt',
#  'chr1_KI270761v1_alt',
#  'chr9_KI270717v1_random',
#  'chr5_KI270793v1_alt',
#  'chr22_KI270928v1_alt',
#  'chr3_KI270895v1_alt',
#  'chrUn_KI270743v1',
#  'chr19_KI270891v1_alt',
#  'chr16_KI270855v1_alt',
#  'chr4_KI270789v1_alt',
#  'chrUn_GL000214v1',
# ...

# %%
list(set(chrs)-set(fa_chrs))
# Out:
# ['KI270711.1',
#  'KI270726.1',
#  'KI270748.1',
#  'KI270749.1',
#  'GL000213.1',
#  'GL000221.1',
#  'KI270742.1',
#  'GL000218.1',
#  'KI270745.1',
#  'KI270744.1',
#  'GL000205.2',
#  'KI270743.1',
#  'KI270722.1',
#  'KI270706.1',
#  'KI270731.1',
#  'KI270733.1',
#  'KI270755.1',
#  'KI270720.1',
#  'GL000224.1',
#  'KI270746.1',
#  'KI270719.1',
#  'KI270727.1',
#  'KI270753.1',
#  'KI270710.1',
#  'SIRVome_isoforms',
#  'GL000220.1',
#  'KI270721.1',
#  'KI270741.1',
#  'KI270751.1',
#  'GL000225.1',
#  'KI270750.1',
#  'KI270725.1',
#  'KI270442.1',
#  'KI270712.1',
#  'KI270734.1',
#  'GL000008.2',
#  'KI270713.1',
#  'GL000194.1',
#  'KI270718.1',
#  'KI270717.1',
#  'KI270754.1',
#  'GL000219.1',
#  'KI270714.1',
#  'GL000195.1',
#  'KI270728.1',
#  'GL000214.1',
#  'GL000009.2']

# %%
from collections import defaultdict
chr_map = defaultdict(list)
for c in chrs:
    if c not in fa_chrs:
        for fa_c in fa_chrs:
            thing = c.split('.')[0]
            if thing in fa_c:
                chr_map[c].append(fa_c)
    else:
        chr_map[c].append(c)

# %%
# chr_map

# %%
for key, item in chr_map.items():
    assert len(item) == 1

# %%
df = pd.DataFrame.from_dict(chr_map, orient='index')
df.reset_index(inplace=True)
df.rename({'index':'gff_chr', 0:'fa_chr'}, axis=1, inplace=True)

df.to_csv('chr_map.tsv', sep='\t')

# %% [markdown]
# ## 230623 seq. cerb annot

# %%
config_fname = '230614_config.tsv'
df = parse_input_config(config, config_fname, 'all')

# todo
df = df.loc[df.species == 'mouse']

datasets = df.dataset.tolist()
species = df.species.tolist()
max_cerberus_run = len(datasets) # TODO modify to work w/ multiple species
# Out:
# 88

# %%
max_cerberus_run
# Out:
# 40

# %% [markdown]
# ## 230621 why no ref ends

# %%
# data config
from utils import *

config_fname = '230614_config.tsv'
df = parse_input_config(config, config_fname, 'all')
df = df.loc[df.species == 'mouse']

datasets = df.dataset.tolist()

def get_df_col(df, q_col, q_col_val, t_col):
    return df.loc[df[q_col]==q_col_val, t_col].tolist()

def get_agg_settings(end_mode, species, param='files'):
    settings = {}
    files = []
    sources = []

    if 'end_mode':
        ic = False
    else:
        ic = True

    # get reference ics / tsss / tess first
    # first source is 'cerberus' to indicate
    # preservation of source / novelty
    if ic == True:
        files += [config['ref']['ics']]
    else:
        files += expand(config['ref']['ends'],
                        zip,
                        end_mode=end_mode,
                        species=species)
    sources += ['gencode']

    # then get the files from each study
    # use the datasets as the sources
    if ic == True:
        files += expand(expand(config['data']['cerb']['ics'],
               zip,
               dataset=get_df_col(df, 'species', species, 'dataset'),
               allow_missing=True),
               species=species)
    else:
        files += expand(expand(config['data']['cerb']['ends'],
               zip,
               dataset=get_df_col(df, 'species', species, 'dataset'),
               allow_missing=True),
               species=species,
               end_mode=end_mode)
    sources += datasets

    settings['file'] = files
    settings['source'] = sources

    return settings[param]
# Out:
# 88

# %%
expand(config['data']['cerb']['agg_ends'],
           species='mouse',
           end_mode='tss')[0]
# Out:
# 'data/mouse/cerberus/agg_tss.bed'

# %%
expand(config['data']['cerb']['agg_ends'],
                              species='mouse',
                              end_mode='tes')[0]
# Out:
# 'data/mouse/cerberus/agg_tes.bed'

# %%
get_agg_settings('tss', 'mouse', 'file')
# Out:
# ['ref/mouse/tss.bed',
#  'data/mouse/cerberus/ESC_Embryo_pacBioSII_pre-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/ESC_Embryo_pacBioSII_post-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/ESC_Embryo_ont_pre-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/ESC_Embryo_ont_post-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/WBlood_Adult_pacBioSII_pre-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/WBlood_Adult_pacBioSII_post-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/WBlood_Adult_ont_pre-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/WBlood_Adult_ont_post-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/TpoolA_Adult_pacBioSII_pre-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/TpoolA_Adult_pacBioSII_post-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/TpoolA_Adult_ont_pre-capture_mouse_all/tss.bed',
#  'data/mouse/cerberus/TpoolA_Adult_ont_post-capture_mouse_all/tss.bed',
# ...

# %% [markdown]
# ## 230620 WHHHHYYY SNAKEMAKE

# %%
bad_env = ['/data/homezvol1/freese/miniconda3/envs/SQANTI3.env',\
           '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python310.zip',\
           '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10',\
           '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/lib-dynload',\
           '/data/homezvol1/freese/.local/lib/python3.10/site-packages',\
           '/dfs8/pub/freese/mortazavi_lab/bin/gencode_utr_fix',\
           '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages',\
           '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/bcbio_gff-0.6.6-py2.7.egg',\
           '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/cupcake-29.0.0-py3.10-linux-x86_64.egg',\
           '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/sklearn-0.0.post5-py3.10.egg',\
           '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/bcbio_gff-0.7.0-py3.10.egg']
print(len(bad_env))
# Out:
# 11

# %%
good_env = ['/data/homezvol1/freese/miniconda3/envs/SQANTI3.env',\
            '/share/crsp/lab/seyedam/freese/mortazavi_lab/data/230526_gencode',\
            '/data/homezvol1/freese/mortazavi_lab/bin/cDNA_Cupcake/sequence',\
            '/data/homezvol1/freese/mortazavi_lab/bin/cDNA_Cupcake',\
            '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python310.zip',\
            '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10',\
            '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/lib-dynload',\
            '/data/homezvol1/freese/.local/lib/python3.10/site-packages',\
            '/dfs8/pub/freese/mortazavi_lab/bin/gencode_utr_fix',\
            '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages',\
            '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/bcbio_gff-0.6.6-py2.7.egg',\
            '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/cupcake-29.0.0-py3.10-linux-x86_64.egg',\
            '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/sklearn-0.0.post5-py3.10.egg',\
            '/data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/bcbio_gff-0.7.0-py3.10.egg']
print(len(good_env))
# Out:
# 14

# %%
# commons
common = list(set(good_env)&(set(bad_env)))
print(len(common))
for c in common:
    print(c)
# Out:
# 11
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/lib-dynload
# /data/homezvol1/freese/.local/lib/python3.10/site-packages
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python310.zip
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/bcbio_gff-0.7.0-py3.10.egg
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/bcbio_gff-0.6.6-py2.7.egg
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/sklearn-0.0.post5-py3.10.egg
# /dfs8/pub/freese/mortazavi_lab/bin/gencode_utr_fix
# /data/homezvol1/freese/miniconda3/envs/SQANTI3.env/lib/python3.10/site-packages/cupcake-29.0.0-py3.10-linux-x86_64.egg

# %%
# only in good
good = list(set(good_env)-(set(bad_env)))
print(len(good))
for c in good:
    print(c)
# Out:
# 3
# /data/homezvol1/freese/mortazavi_lab/bin/cDNA_Cupcake/sequence
# /share/crsp/lab/seyedam/freese/mortazavi_lab/data/230526_gencode
# /data/homezvol1/freese/mortazavi_lab/bin/cDNA_Cupcake

# %%
# only in bad

# %% [markdown]
# ## 230616 getting expression values

# %%
def get_ab_from_gff(gff_file, ofile):
    df = pr.read_gff(gff_file).as_df() 
    df = df[['transcript_id', 'flrpm', 'rpm']]
    df = df.drop_duplicates()
    assert len(df.loc[df.transcript_id.duplicated(keep=False)].index) == 0
    df.to_csv(ofile, sep='\t', index=False)

# %%
gff_file = 'data/human/Brain_Embryo_ont_pre-capture_human_all.gff'
ofile = 'data/human/Brain_Embryo_ont_pre-capture_human_all_abundance.tsv'
get_ab_from_gff(gff_file, ofile)

# %%
df = pr.read_gff('data/human/Brain_Embryo_ont_pre-capture_human_all.gff').as_df()

# %%
df = df[['transcript_id', 'flrpm', 'rpm']]

# %%
print(len(df.index))
df = df.drop_duplicates()
print(len(df.index))
# Out:
# 213704
# 51638

# %%
df.loc[df.transcript_id.duplicated(keep=False)].sort_values(by='transcript_id')
# Out:
# Empty DataFrame
# Columns: [transcript_id, flrpm, rpm]
# Index: []

# %%
df.head()
# Out:
#                                         transcript_id      flrpm         rpm
# 0   ont-Crg-CapTrap_HpreCap_0+_EmbBrain01Rep1.NAM_...  25.271982   25.271982
# 3   ont-Crg-CapTrap_HpreCap_0+_EmbBrain01Rep1.NAM_...  16.847988   33.695976
# 8   ont-Crg-CapTrap_HpreCap_0+_EmbBrain01Rep1.NAM_...  33.695976  623.375556
# 9   ont-Crg-CapTrap_HpreCap_0+_EmbBrain01Rep1.NAM_...  16.847988   210.59985
# 10  ont-Crg-CapTrap_HpreCap_0+_EmbBrain01Rep1.NAM_...  16.847988   75.815946

# %% [markdown]
# ## 230615 input parsing

# %%
def parse_input_config(config, config_file, subset):
    df = pd.read_csv(config_file, sep='\t')
    df['dataset'] = df.fname.str.split('.', n=1, expand=True)[0]
    df['subset'] = np.nan
    df.loc[df.fname.str.contains('all.gff.gz'), 'subset'] = 'all'
    df.loc[df.fname.str.contains('cagePolyASupported.gff.gz'), 'subset'] = 'supported'

    # add the metadata
    species = ['human', 'mouse']
    meta_df = pd.DataFrame()
    for s in species:
        temp = pd.read_csv(expand(config['data']['meta'], species=s)[0],
                           sep='\t')
        temp['species'] = s
        meta_df = pd.concat([meta_df, temp], axis=0)

    df = df.merge(meta_df, on='dataset', how='left')
    df['temp'] = df['tissue']+'_'+\
                 df['age']+'_'+\
                 df['platform']+'_'+\
                 df['capture']+'_'+\
                 df['species']+'_'+\
                 df['subset']
    
    df = df.loc[df.subset==subset]
    print(len(df.temp.unique()))
    # print(df.head())
    return df

# %%
df = parse_input_config(config, '230614_config.tsv', 'all')
# Out:
# 88
#                                                fname  \
# 1  SIDMWbEPP0101.splicing_status-all.endSupport-a...
# 3  SIDMWbEPC0101.splicing_status-all.endSupport-a...
# 5  SIDMWbEOP0101.splicing_status-all.endSupport-a...
# 7  SIDMWbEOC0101.splicing_status-all.endSupport-a...
# 9  SIDMWbAPP0101.splicing_status-all.endSupport-a...
#
#                                                 path        dataset subset  \
# 1  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPP0101    all
# 3  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPC0101    all
# 5  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEOP0101    all
# 7  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEOC0101    all
# 9  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbAPP0101    all
#
#    tissue     age   platform       capture  rep1  rep2 species  \
# 1     ESC  Embryo  pacBioSII   pre-capture     1     1   mouse
# ...

# %%
df = pd.read_csv('230614_config.tsv', sep='\t')
df['dataset_id'] = df.fname.str.split('.', n=1, expand=True)[0]
df['subset'] = np.nan
df.loc[df.fname.str.contains('all.gff.gz'), 'subset'] = 'all'
df.loc[df.fname.str.contains('cagePolyASupported.gff.gz'), 'subset'] = 'supported'

# add the metadata
species = ['human', 'mouse']
meta_df = pd.DataFrame()
for s in species:
    temp = pd.read_csv(expand(config['data']['meta'], species=s)[0],
                       sep='\t')
    temp['species'] = s
    meta_df = pd.concat([meta_df, temp], axis=0)

df = df.merge(meta_df, on='dataset', how='left')
print(len(df.index))
print(len(df.dataset.unique()))
df['dataset'] = df['tissue']+'_'+\
             df['age']+'_'+\
             df['platform']+'_'+\
             df['capture']+'_'+\
             df['species']+'_'+\
             df['subset']
print(len(df.temp.unique()))
print(df.head())
# Out:
# 176
# 88
# 176
#                                                fname  \
# 0  SIDMWbEPP0101.splicing_status-all.endSupport-c...
# 1  SIDMWbEPP0101.splicing_status-all.endSupport-a...
# 2  SIDMWbEPC0101.splicing_status-all.endSupport-c...
# 3  SIDMWbEPC0101.splicing_status-all.endSupport-a...
# 4  SIDMWbEOP0101.splicing_status-all.endSupport-c...
#
#                                                 path        dataset  \
# 0  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPP0101
# 1  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPP0101
# 2  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPC0101
# 3  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPC0101
# 4  https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEOP0101
#
#       subset tissue     age   platform       capture  rep1  rep2 species  \
# 0  supported    ESC  Embryo  pacBioSII   pre-capture     1     1   mouse
# ...

# %%
df['link'] = df.path+df.fname

# %%
datasets = df.dataset.tolist()
species = df.species.tolist()
# Out:
#                                                  fname  \
# 0    SIDMWbEPP0101.splicing_status-all.endSupport-c...
# 1    SIDMWbEPP0101.splicing_status-all.endSupport-a...
# 2    SIDMWbEPC0101.splicing_status-all.endSupport-c...
# 3    SIDMWbEPC0101.splicing_status-all.endSupport-a...
# 4    SIDMWbEOP0101.splicing_status-all.endSupport-c...
# ..                                                 ...
# 171  SIDHBrAPC0301.splicing_status-all.endSupport-a...
# 172  SIDHBrAOP0301.splicing_status-all.endSupport-c...
# 173  SIDHBrAOP0301.splicing_status-all.endSupport-a...
# 174  SIDHBrAOC0301.splicing_status-all.endSupport-c...
# 175  SIDHBrAOC0301.splicing_status-all.endSupport-a...
#
#                                                   path        dataset  \
# 0    https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPP0101
# 1    https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPP0101
# 2    https://public-docs.crg.es/rguigo/Data/gkaur/L...  SIDMWbEPC0101
# ...

# %%
config_file = 'config.yml'
with open(config_file) as f:
    config = yaml.safe_load(f)

# %%
config['data']['cerberus']['agg_ends']
# Out:
# 'data/{species}/bepis_{end_type}_agg.bed'

# %%
expand(                         config['data']['cerberus']['agg_ends'],
       zip,
                                species='human',
                                end_type='tes',
                                allow_missing=True)
# Out:
# ['data/human/bepis_tes_agg.bed']
